# %%
# !pip install pyspark
# Out:
# ...
#   Using cached pyspark-4.0.1.tar.gz (434.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Using cached py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# ...
#   Created wheel for pyspark: filename=pyspark-4.0.1-py2.py3-none-any.whl size=434813860 sha256=9bad8e887b78a8577cf1dfd123828db81fefda8141e448da2dc3653cb15314c5
#   Stored in directory: /Users/sourabh/Library/Caches/pip/wheels/a1/70/d4/2677f8b10c903e8bed0e828f10297861ee280649b88266b047
# Successfully built pyspark
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pyspark]m1/2 [pyspark]
# ...

# %%
# creating spark session 


from pyspark.sql import SparkSession

spark = (
    SparkSession
    .builder
    .appName("Spark Introduction")
    .master("local[*]")
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/14 17:59:30 WARN Utils: Your hostname, SOUS-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.11 instead (on interface en0)
# 25/11/14 17:59:30 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/14 17:59:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.11:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark Introduction</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# emp dat and  and schema 

emp_data = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"],
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","Female","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
# create data frame 

emp=spark.createDataFrame(data=emp_data,schema=emp_schema)

# %%
# cheack the no of partitions 

# spark read the data in the form of partitions 

emp.rdd.getNumPartitions()
# Out:
# 10

# %%
# show the data 

emp.show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# ...

# %%
# we have to filter out emp salary > 50000

emp_final=emp.where("salary >50000")

# %%
emp_final.rdd.getNumPartitions()
# Out:
# 10

# %%
# write data to output as a action in csv format

emp_final.write.format("csv").save("data/output/1/emp.csv")
